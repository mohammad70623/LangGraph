# %%
from langgraph.graph import StateGraph
from typing import TypedDict

# %%
class BatsmanState(TypedDict):

    balls: int
    runs: int
    fours: int
    sixes: int

    sr: float
    bpb: float
    boundary_percent: float
    summary: str

# %%
def calculate_sr(state: BatsmanState):
    sr = (state['runs']/state['balls'])*100
    state['sr']=sr
    return state

# %%
graph = StateGraph(BatsmanState)

graph.add_node('calculate_sr', calculate_sr)
graph.add_node('calculate_bpr', calculate_bpr)
graph.add_node('calculate_boundary_percent', calculate_boundary_percent)
graph.add_node('summary', summary)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 graph = StateGraph(BatsmanState)
#       3 graph.add_node('calculate_sr', calculate_sr)
# ----> 4 graph.add_node('calculate_bpr', calculate_bpr)
#       5 graph.add_node('calculate_boundary_percent', calculate_boundary_percent)
#       6 graph.add_node('summary', summary)
#
# NameError: name 'calculate_bpr' is not defined
